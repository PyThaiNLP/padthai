# %% [markdown]
# # Thai ChatBot from Few-shot learning with Flex GPT-2-base

# %%
# !pip install padthai
# Out:
# Collecting padthai
#   Downloading padthai-0.1.dev0-py3-none-any.whl (10 kB)
# Collecting transformers<5.0
#   Downloading transformers-4.9.1-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 5.7 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers<5.0->padthai) (21.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0->padthai) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0->padthai) (4.41.1)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 44.6 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0->padthai) (3.0.12)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0->padthai) (1.19.5)
# Collecting huggingface-hub==0.0.12
#   Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 45.1 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 40.2 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0->padthai) (4.6.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0->padthai) (2019.12.20)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub==0.0.12->transformers<5.0->padthai) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers<5.0->padthai) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0->padthai) (3.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0->padthai) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0->padthai) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0->padthai) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0->padthai) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0->padthai) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0->padthai) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0->padthai) (1.0.1)
# Installing collected packages: tokenizers, sacremoses, pyyaml, huggingface-hub, transformers, padthai
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.0.12 padthai-0.1.dev0 pyyaml-5.4.1 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.9.1

# %%
data = [
        """
        Q: สวัสดี\n
        A: สวัสดีจ้า\n
        Q: ทำอะไรอยู่\n
        A: กำลังนั่งเล่นจ้า แล้วคุณล่ะ\n
        Q: กำลังกินข้าวเหมือนกัน\n
        A: จ้า ^_^
        """,
        """
        Q: ร้องเพลงให้ฟังหน่อย\n
        A: ช้าง ช้าง ช้าง น้องเคยเห็นช้ารึเปล่า\n
        Q: เลือกเพลงได้ดีนี่\n
        A: ฮา ฮา คุณก็ลองบ้างสิ\n
        Q: ไม่ดีกว่าน่า\n
        A: โกงนี่น่า
        """,
        """
        Q: เครียดกับโควิดจริง ๆ ช่วงนี้\n
        A: พยายามทำใจให้สบายนะ :)
        """
]

# %%
from padthai import *

# %%
flexgpt2_model = FlexGPT2FewShot('./flex-model1')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1243931.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=902146.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=24.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=90.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=208.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=2247311.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=864.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=510401385.0, style=ProgressStyle(descri…

# %%
flexgpt2_model.train(
    data,
    logging_dir='./log_model_flex',
    num_train_epochs=330,
    train_size=0.9,
    batch_size=8,
    save_every_epochs=False
)
# Out:
# ***** Running training *****
#   Num examples = 3
#   Num Epochs = 330
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 330
#     <div>
#
#       <progress value='330' max='330' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [330/330 02:13, Epoch 330/330]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.155400</td>
#       <td>8.223073</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.712400</td>
#       <td>7.859550</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.475800</td>
#       <td>7.629242</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.292700</td>
#       <td>7.438305</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.123000</td>
#       <td>7.275018</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.965900</td>
#       <td>7.140943</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.835300</td>
#       <td>7.031989</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td
td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.602200</td>
#       <td>1.297915</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.579800</td>
#       <td>1.248329</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.558400</td>
#       <td>1.200667</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.537900</td>
#       <td>1.154635</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.518200</td>
#       <td>1.110406</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.499300</td>
#       <td>1.068170</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.481100</td>
#       <td>1.027681</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.463700</td>
#       <td>0.988968</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.446900</td>
#       <td>0.952015</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.430900</td>
#       <td>0.916624</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.415400</td>
#       <td>0.882800</t
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# ***** Running Evaluation *****
#   Num examples = 1
#   Batch size = 8
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 : < :]
#     </div>
# Saving model checkpoint to ./flex-model1
# Configuration saved in ./flex-model1/config.json
# Model weights saved in ./flex-model1/pytorch_model.bin

# %%
flexgpt2_model.gen("""
Q: ร้องเพลงให้ฟังหน่อย\n
A:""",max_length=100)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ['\nQ: ร้องเพลงให้ฟังหน่อย\n\nA: ช้าง ช้าง น้องเคยเห็นช้ารึเปล่า\nA: ช้ากว่า ช้ากว่า เปรียบเทียบ ช้า เปรียบเทียบเปรียบเทียบเปรียบเทียบเปรียบเทียบเปรียบเทียบ\nA: ช้ากว่า เปรียบเทียบ เปรียบเทียบ',
#  '\nQ: ร้องเพลงให้ฟังหน่อย\n\nA: ช้าง ช้าง ช้าง น้องเคยเห็นช้ารึเปล่า\nA: ช้ารึเปล่า ช้ารึเปล่า ช้ารึเปล่า แล้วช้ารึเปล่า\nA: ไม่ดีกว่าน่า ช้ารึเปล่า ช้ารึเปล่า แล้',
#  '\nQ: ร้องเพลงให้ฟังหน่อย\n\nA: ช้าง ช้าง ช้าง น้องเคยเห็นช้ารึเปล่า\nA: ช้ารึเปล่า ช้ารึเปล่า ช้ารึเปล่า ช้ารึเปล่า ช้ารึเปล่า\nA: ช้ารึเปล่า ช้ารึเปล่า ช้ารึเปล่',
#  '\nQ: ร้องเพลงให้ฟังหน่อย\n\nA: ช้าง ช้าง ช้าง น้องเคยเห็นช้ารึเปล่า\nA: นี่คือร้องเพลงให้ฟังหน่อย แต่ก็ลองบ้างสิ\nA: เลือกร้องเพลงให้เหมาะกับเรา แต่ถ้าชอบฟังน่าจะดีกว่า เพราะแต่ละคน',
#  '\nQ: ร้องเพลงให้ฟังหน่อย\n\nA: ช้าง ช้าง ช้าง น้องเคยเห็นช้ารึเปล่า\nA: ช้ากว่า ช้ากว่า มากกว่า หรือ ช้ากว่า หรือ ช้ากว่า บ้าง\nA: ต้องลองสักครั้งน่า ถึงจะรู้ว่า ถ้าได้']
